# %%
import pandas as pd

# %%
df= pd.read_csv('Bengaluru_House_Data.csv')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', nan, '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df.dropna(inplace=True)

# %%
df['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '3 Bedroom', '1 RK', '4 BHK',
#        '1 BHK', '5 BHK', '11 BHK', '5 Bedroom', '9 BHK', '2 Bedroom',
#        '6 BHK', '7 BHK', '6 Bedroom'], dtype=object)

# %%
df['size'] = df['size'].apply(lambda x: x.split()[0])

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
#change Data type of Df col -- astype
# Out:
#                   area_type   availability                  location size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II    2
# 1                Plot  Area  Ready To Move          Chikka Tirupathi    4
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli    3
# 5      Super built-up  Area  Ready To Move                Whitefield    2
# 11               Plot  Area  Ready To Move                Whitefield    4
# ...                     ...            ...                       ...  ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli    3
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout    3
# 13315        Built-up  Area  Ready To Move                Whitefield    5
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar    2
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar    4
#
#        society total_sqft  bath  balcony   price
# ...

# %%
df['size']  = df['size'].astype('int64')

# %%
int32
int64
float 
float

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size              int64
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size              int64
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df['size']  = df['size'].astype('int64')

# %%
df.dtypes

# %%
sheet = ['python','java','aws']
df_list = []
for s in  sheet:
    df_list.append(pd.read_excel('assigmentmyself.xlsx',sheet_name=None))
final_df = pd.concat(df_list)

# %%
final_df
# Out:
#          name    city
# 0        test    pune
# 1      sample  mumbai
# 2     sample1    pune
# 3     asdfasd  python
# 0     asfasdf    pune
# 1   sfsadfsdf  asfasd
# 2  asddfsdfsd    java
# 0       rasdf    pune
# 1      safsdf  mumbai
# 2     sdafsdf    pune
# 3       sdfsd     aws

# %%
del final_df

# %%
import openpyxl
import os
df_list= []
filename = [file for file in os.listdir() if file.startswith('assigment')][0]
sheetname = openpyxl.load_workbook(filename).sheetnames
for sheet in  sheetname:
    if sheet not in []:
        df_list.append(pd.read_excel(filename,sheet_name=sheet))
final_df = pd.concat(df_list)

# %%
final_df
# Out:
#          name    city
# 0        test    pune
# 1      sample  mumbai
# 2     sample1    pune
# 3     asdfasd  python
# 0     asfasdf    pune
# 1   sfsadfsdf  asfasd
# 2  asddfsdfsd    java
# 0       rasdf    pune
# 1      safsdf  mumbai
# 2     sdafsdf    pune
# 3       sdfsd     aws

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [95], in <cell line: 1>()
# ----> 1 df.idxmax()
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:10291, in DataFrame.idxmax(self, axis, skipna)
#   10229 """
#   10230 Return index of first occurrence of maximum over requested axis.
#   10231
#    (...)
#   10287 dtype: object
#   10288 """
#   10289 axis = self._get_axis_number(axis)
# > 10291 res = self._reduce(
#   10292     nanops.nanargmax, "argmax", axis=axis, skipna=skipna, numeric_only=False
#   10293 )
#   10294 indices = res._values
#   10296 # indices will always be np.ndarray since axis is not None and
#   10297 # values is a 2d array for DataFrame
#   10298 # error: Item "int" of "Union[int, Any]" has no attribute "__iter__"
#
# ...
